# %%
import json
import numpy
import pandas as pd
import io

# %%
file_path = '../available_data/history.json'

# %%
df = pd.read_json(file_path, lines=True)

# %%
df
# Out:
#        number                                            history
# 0      300000  [{'timestamp_from': '18.01.2022 08:50', 'times...
# 1      300001  [{'timestamp_from': '12.01.2022 10:45', 'times...
# 2      300002  [{'timestamp_from': '17.01.2022 08:42', 'times...
# 3      300003  [{'timestamp_from': '22.02.2022 16:16', 'times...
# 4      300004  [{'timestamp_from': '12.01.2022 10:08', 'times...
# ...       ...                                                ...
# 47097  350020  [{'timestamp_from': '21.11.2022 09:38', 'times...
# 47098  350021  [{'timestamp_from': '03.11.2022 13:03', 'times...
# 47099  350022  [{'timestamp_from': '14.12.2022 16:07', 'times...
# 47100  350023  [{'timestamp_from': '02.11.2022 13:28', 'times...
# 47101  350024  [{'timestamp_from': '12.11.2022 07:15', 'times...
#
# [47102 rows x 2 columns]

# %%
pd.json_normalize(df.history[0])
# Out:
#      timestamp_from      timestamp_to                 reason  \
# 0  18.01.2022 08:50                     Получено уведомление
# 1  18.01.2022 08:50  20.01.2022 09:59   Получено уведомление
# 2  18.01.2022 08:50  20.01.2022 09:26   Получено уведомление
# 3  12.01.2022 10:02  18.01.2022 08:50  В процес на обработка
# 4  12.01.2022 10:02  18.01.2022 08:20  В процес на обработка
# 5  12.01.2022 08:49  12.01.2022 10:02
#
#                   change
# 0    Получил уведомление
# 1        Очакващ отговор
# 2    Получил уведомление
# 3        Очакващ отговор
# 4  В процес на обработка
# 5        Чакащ обработка

# %%
def json_to_series(text):
    keys, values = zip(*[(dct['label'], dct['value']) for dct in json.loads(text)])
    return pd.Series(values, index=keys)

# %%
data = []

with open(file_path, encoding='utf-8') as file:
    for line in file:
        obj = json.loads(line)
        data.append(obj)

# %%
json_string = json.dumps(data)  # Convert data list to JSON string
json_dict = json.loads(json_string)  # Load JSON string as a Python object

# %%
combined_dict = {
    'number': [obj['number'] for obj in json_dict],
    'history': [obj['history'] for obj in json_dict]
}

df = pd.concat([pd.DataFrame(combined_dict), pd.DataFrame(list(combined_dict['history']))], axis=1).drop('history', 1)
# Out:
# C:\Users\ebasii\AppData\Local\Temp\ipykernel_69036\4063556822.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = pd.concat([pd.DataFrame(combined_dict), pd.DataFrame(list(combined_dict['history']))], axis=1).drop('history', 1)

# %%
df[df[2].notnull()]
# Out:
#        number                                                  0  \
# 0      300000  {'timestamp_from': '18.01.2022 08:50', 'timest...
# 2      300002  {'timestamp_from': '17.01.2022 08:42', 'timest...
# 3      300003  {'timestamp_from': '22.02.2022 16:16', 'timest...
# 4      300004  {'timestamp_from': '12.01.2022 10:08', 'timest...
# 5      300005  {'timestamp_from': '12.01.2022 10:10', 'timest...
# ...       ...                                                ...
# 47097  350020  {'timestamp_from': '21.11.2022 09:38', 'timest...
# 47098  350021  {'timestamp_from': '03.11.2022 13:03', 'timest...
# 47099  350022  {'timestamp_from': '14.12.2022 16:07', 'timest...
# 47100  350023  {'timestamp_from': '02.11.2022 13:28', 'timest...
# 47101  350024  {'timestamp_from': '12.11.2022 07:15', 'timest...
#
#                                                        1  \
# 0      {'timestamp_from': '18.01.2022 08:50', 'timest...
# 2      {'timestamp_from': '17.01.2022 08:32', 'timest...
# 3      {'timestamp_from': '15.01.2022 18:26', 'timest...
# 4      {'timestamp_from': '12.01.2022 10:08', 'timest...
# 5      {'timestamp_from': '12.01.2022 10:10', 'timest...
# ...                                                  ...
# 47097  {'timestamp_from': '28.10.2022 16:26', 'timest...
# 47098  {'timestamp_from': '22.10.2022 07:56', 'timest...
# 47099  {'timestamp_from': '28.10.2022 16:32', 'timest...
# 47100  {'timestamp_from': '26.10.2022 14:44', 'timest...
# 47101  {'timestamp_from': '21.10.2022 08:50', 'timest...
#
#                                                        2  \
# 0      {'timestamp_from': '18.01.2022 08:50', 'timest...
# 2      {'timestamp_from': '12.01.2022 10:06', 'timest...
# 3      {'timestamp_from': '12.01.2022 10:07', 'timest...
# 4      {'timestamp_from': '12.01.2022 10:08', 'timest...
# 5      {'timestamp_from': '12.01.2022 10:10', 'timest...
# ...                                                  ...
# 47097  {'timestamp_from': '20.10.2022 11:46', 'timest...
# 47098  {'timestamp_from': '20.10.2022 11:58', 'timest...
# 47099  {'timestamp_from': '20.10.2022 11:59', 'timest...
# 47100  {'timestamp_from': '20.10.2022 12:36', 'timest...
# 47101  {'timestamp_from': '20.10.2022 11:59', 'timest...
#
#                                                        3  \
# 0      {'timestamp_from': '12.01.2022 10:02', 'timest...
# 2      {'timestamp_from': '12.01.2022 08:52', 'timest...
# 3      {'timestamp_from': '12.01.2022 08:52', 'timest...
# 4      {'timestamp_from': '12.01.2022 09:10', 'timest...
# 5      {'timestamp_from': '12.01.2022 09:13', 'timest...
# ...                                                  ...
# 47097  {'timestamp_from': '20.10.2022 11:46', 'timest...
# 47098  {'timestamp_from': '20.10.2022 11:52', 'timest...
# 47099  {'timestamp_from': '20.10.2022 11:54', 'timest...
# 47100  {'timestamp_from': '20.10.2022 11:56', 'timest...
# 47101  {'timestamp_from': '20.10.2022 11:57', 'timest...
#
#                                                        4  \
# 0      {'timestamp_from': '12.01.2022 10:02', 'timest...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# 5                                                   None
# ...                                                  ...
# 47097                                               None
# 47098                                               None
# 47099                                               None
# 47100                                               None
# 47101                                               None
#
#                                                        5     6     7     8  \
# 0      {'timestamp_from': '12.01.2022 08:49', 'timest...  None  None  None
# 2                                                   None  None  None  None
# 3                                                   None  None  None  None
# 4                                                   None  None  None  None
# 5                                                   None  None  None  None
# ...                                                  ...   ...   ...   ...
# 47097                                               None  None  None  None
# 47098                                               None  None  None  None
# 47099                                               None  None  None  None
# 47100                                               None  None  None  None
# 47101                                               None  None  None  None
#
#           9
# 0      None
# 2      None
# 3      None
# 4      None
# 5      None
# ...     ...
# 47097  None
# 47098  None
# 47099  None
# 47100  None
# 47101  None
#
# [43881 rows x 11 columns]

# %%
df_expanded = df['number'].to_frame()  # Create a dataframe with the 'number' column
for col_name in df.columns:
    if col_name != 'number':
        expanded_df = pd.json_normalize(df[col_name]).add_suffix(f"_{col_name}")
        df_expanded = pd.concat([df_expanded, expanded_df], axis=1)

# %%
df_expanded
# Out:
#        number  timestamp_from_0 timestamp_to_0               reason_0  \
# 0      300000  18.01.2022 08:50                  Получено уведомление
# 1      300001  12.01.2022 10:45                 В процес на обработка
# 2      300002  17.01.2022 08:42                  Получено уведомление
# 3      300003  22.02.2022 16:16                  Получено уведомление
# 4      300004  12.01.2022 10:08                 В процес на обработка
# ...       ...               ...            ...                    ...
# 47097  350020  21.11.2022 09:38                  Получено уведомление
# 47098  350021  03.11.2022 13:03                  Получено уведомление
# 47099  350022  14.12.2022 16:07                  Получено уведомление
# 47100  350023  02.11.2022 13:28                  Получено уведомление
# 47101  350024  12.11.2022 07:15                  Получено уведомление
#
#                     change_0  timestamp_from_1    timestamp_to_1  \
# 0        Получил уведомление  18.01.2022 08:50  20.01.2022 09:59
# 1      В процес на обработка  12.01.2022 08:50  12.01.2022 10:45
# 2        Получил уведомление  17.01.2022 08:32  17.01.2022 08:42
# 3        Получил уведомление  15.01.2022 18:26  15.01.2022 18:28
# 4        Получил уведомление  12.01.2022 10:08  14.01.2022 09:04
# ...                      ...               ...               ...
# 47097    Получил уведомление  28.10.2022 16:26  28.10.2022 16:51
# 47098    Получил уведомление  22.10.2022 07:56  22.10.2022 08:27
# 47099    Получил уведомление  28.10.2022 16:32  28.10.2022 16:52
# 47100    Получил уведомление  26.10.2022 14:44  26.10.2022 14:45
# 47101    Получил уведомление  21.10.2022 08:50  21.10.2022 09:28
#
#                     reason_1         change_1  timestamp_from_2  ... reason_7  \
# 0       Получено уведомление  Очакващ отговор  18.01.2022 08:50  ...      NaN
# 1                             Чакащ обработка               NaN  ...      NaN
# 2            Очакващ отговор  Очакващ отговор  12.01.2022 10:06  ...      NaN
# 3            Очакващ отговор  Очакващ отговор  12.01.2022 10:07  ...      NaN
# 4      В процес на обработка  Очакващ отговор  12.01.2022 10:08  ...      NaN
# ...                      ...              ...               ...  ...      ...
# 47097        Очакващ отговор  Очакващ отговор  20.10.2022 11:46  ...      NaN
# 47098        Очакващ отговор  Очакващ отговор  20.10.2022 11:58  ...      NaN
# 47099        Очакващ отговор  Очакващ отговор  20.10.2022 11:59  ...      NaN
# 47100        Очакващ отговор  Очакващ отговор  20.10.2022 12:36  ...      NaN
# 47101        Очакващ отговор  Очакващ отговор  20.10.2022 11:59  ...      NaN
#
#       change_7 timestamp_from_8 timestamp_to_8 reason_8 change_8  \
# 0          NaN              NaN            NaN      NaN      NaN
# 1          NaN              NaN            NaN      NaN      NaN
# 2          NaN              NaN            NaN      NaN      NaN
# 3          NaN              NaN            NaN      NaN      NaN
# 4          NaN              NaN            NaN      NaN      NaN
# ...        ...              ...            ...      ...      ...
# 47097      NaN              NaN            NaN      NaN      NaN
# 47098      NaN              NaN            NaN      NaN      NaN
# 47099      NaN              NaN            NaN      NaN      NaN
# 47100      NaN              NaN            NaN      NaN      NaN
# 47101      NaN              NaN            NaN      NaN      NaN
#
#       timestamp_from_9 timestamp_to_9 reason_9 change_9
# 0                  NaN            NaN      NaN      NaN
# 1                  NaN            NaN      NaN      NaN
# 2                  NaN            NaN      NaN      NaN
# 3                  NaN            NaN      NaN      NaN
# 4                  NaN            NaN      NaN      NaN
# ...                ...            ...      ...      ...
# 47097              NaN            NaN      NaN      NaN
# 47098              NaN            NaN      NaN      NaN
# 47099              NaN            NaN      NaN      NaN
# 47100              NaN            NaN      NaN      NaN
# 47101              NaN            NaN      NaN      NaN
#
# [47102 rows x 41 columns]
